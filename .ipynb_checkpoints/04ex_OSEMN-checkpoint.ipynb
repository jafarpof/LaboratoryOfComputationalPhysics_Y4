# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import numpy as np
import pandas as pd


b=np.random.randint(10,size=80)
file = open("simple_data.txt","w")
for i in range(len(b)):
    file.writelines(str(b[i]) +', ')
file.close()

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
a=[]
for i in range(5):
    c=[]
    b=np.random.randint(10,size=5)
    for j in b:
        c.append(j)
    a.append(c)

file=open("data.txt",'w')
for i in a:
    for j in i:
        file.write(str(j)+str(" "))
    file.write("\n")

file.close()

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import csv

with open('data.csv', 'w+') as csvFile:
    w = csv.writer(csvFile,delimiter=',')
    data = np.loadtxt("data.txt")
    for row in data:
        w.writerow(row)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
vec=[]

with open('data.txt','r') as f:
    with open('data.csv','w') as f2:
        for line in f:
            content=line.split()
            #print(content)
            for i in content:
                f2.write(i)
                f2.write(',')

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
df = pd.read_json('user_data.json')
df_for_csv = df[df['CreditCardType']=='American Express']
df_for_csv.to_csv('user_data.csv')

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import urllib.request
import matplotlib.pyplot as plt
url = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
with urllib.request.urlopen(url) as f:
    data = pd.read_csv(f)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = data["class"]
plt.hist(xs)
plt.xlabel('class value')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
with urllib.request.urlopen(url) as f:
    data = pd.read_csv(f)

# %%
f1= data['features_1']
f2 = data['features_2']
f3 = data['features_3']

fig = plt.figure(figsize=(18,5))

plt.subplot(1, 3, 1)
plt.title("(features_1,features_2)")
plt.scatter(features_1, features_2, alpha=0.6,color = "green")

plt.subplot(1, 3, 2)
plt.title("(features_1,features_3)")
plt.scatter(features_1, features_3, alpha=0.6,color="yellow")

plt.subplot(1, 3, 3)
plt.title("(features_2,features_3)")
plt.scatter(features_2, features_3, alpha=0.6,color="brown")

plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
url = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
with urllib.request.urlopen(url) as file:
    data = pd.read_csv(file)

jason = data.to_json(orient='records')
